# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("runs/mc-0.001-0.001-True-SS100-learnStd=False-8131-1556265262")

# %%
data.loc[data['metric_name'] == "total_reward"].plot(x='episode', y='value')
plt.grid()
