# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("runs/mc-InvertedPendulum-v1-0.01-0.001-True-exp_id=NA-run_id=NA-learnStd=False-seed=7316-use_target=False-1557724366-num_samples=100")

# %%
# ax = data.loc[data['metric_name'] == "total_reward"].plot(x='episode', y='value', color="green", label="MC100")
ax = data.loc[data['metric_name'] == "total_reward"].plot(x='episode', y='value')
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(data.loc[data['metric_name'] == "total_reward"]['value'].values[2600:2650], label="total_reward")
plt.plot(data.loc[data['metric_name'] == "average_q"]['value'].values[2600:2650], label="average_q")
plt.plot(data.loc[data['metric_name'] == "average_v"]['value'].values[2600:2650], label="average_v")
plt.legend()
plt.grid()

# %%
fig = plt.figure()
ax1 = plt.subplot(311)
plt.plot(data.loc[data['metric_name'] == "total_reward"]['value'].values[2640:2700], label="total_reward")
plt.subplot(312, sharex=ax)
plt.plot(data.loc[data['metric_name'] == "average_q"]['value'].values[2640:2700], label="average_q")
plt.subplot(313, sharex=ax)
plt.plot(data.loc[data['metric_name'] == "average_v"]['value'].values[2640:2700], label="average_v")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-3ac2a0058c1f> in <module>
#       1 ax = plt.plot(data.loc[data['metric_name'] == "total_reward"]['value'].values[2640:2700], label="total_reward")
# ----> 2 plt.subplot(data.loc[data['metric_name'] == "average_q"]['value'].values[2640:2700], label="average_q", sharex=ax)
#       3 plt.subplot(data.loc[data['metric_name'] == "average_v"]['value'].values[2640:2700], label="average_v", sharex=ax)
#
# /usr/local/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1082
#    1083     fig = gcf()
# -> 1084     a = fig.add_subplot(*args, **kwargs)
#    1085     bbox = a.bbox
#    1086     byebye = []
#
# /usr/local/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# /usr/local/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      37             else:
#      38                 try:
# ---> 39                     s = str(int(args[0]))
#      40                     rows, cols, num = map(int, s)
#      41                 except ValueError:
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
data.loc[data['metric_name'] == "min_log_prob"]['value'].iloc[2640:2700]
# Out:
# 4593363     -7.482368
# 4595760     -9.809196
# 4596657     -7.804208
# 4597970     -8.900081
# 4599635     -8.088611
# 4600812     -6.892790
# 4601633     -8.324593
# 4602714    -62.191902
# 4603983     -8.118695
# 4605548     -9.229521
# 4606989     -8.604827
# 4608218     -9.004066
# 4609207     -7.494809
# 4611068    -59.209030
# 4612021     -9.306751
# 4613774    -65.581978
# 4614859    -25.145664
# 4616020    -50.100845
# 4616981     -7.459464
# 4618382    -12.062007
# 4619259    -10.075152
# 4620520     -7.796571
# 4621169    -11.613781
# 4621686    -10.021054
# 4622383     -7.083794
# 4623048    -23.452564
# 4624177     -8.482420
# 4624794     -6.484483
# 4625799     -9.110912
# 4626916     -8.912143
# 4627549     -7.723584
# 4628506     -7.819921
# 4629119    -23.938166
# 4630012    -95.019272
# 4631037    -89.490417
# 4631458     -7.379403
# 4632179     -7.713799
# 4632700     -6.355150
# 4633721    -43.357178
# 4634666    -92.475746
# 4635287     -7.355503
# 4636240    -58.421692
# 4636709     -6.535948
# 4637450    -26.672976
# 4638435   -162.069748
# 4638844     -8.048947
# 4639273     -6.060396
# 4639930     -9.561160
# 4640531    -37.460251
# 4641136    -13.158081
# 4641453     -5.652009
# 4642110    -10.855071
# 4642727    -19.403498
# 4643284   -155.008682
# 4643613     -6.684463
# 4644070     -9.459632
# 4644823   -104.957710
# 4645424   -102.883286
# 4645813     -6.670677
# 4646598    -42.156914
# Name: value, dtype: float64
